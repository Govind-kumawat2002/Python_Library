# %% [markdown]
# # linear Regration

# %% [markdown]
# first upon we are import of this library

# %%
import pandas  as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# then we are read of data

# %%
laptop_df= pd.read_csv('laptopPrice.csv')
laptop_df # create a variable
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
laptop_df.isnull().sum() # so we are find null value in df
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
laptop_df.duplicated().sum() # then after we are find duplicated value
# Out:
# 21

# %%
laptop_df.drop_duplicates(inplace=True) # so we are drop of duplicate value in data fram

# %%
laptop_df.shape # find the shape of datafram by using shape function
# Out:
# (802, 19)

# %%
laptop_df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %%
laptop_df['brand'].unique()
dt_brand ={"ASUS":1, "Lenovo":2, "acer":3, "Avita":4, "HP":5, "DELL":6, "MSI":7, "APPLE":8}
laptop_df['brand']=laptop_df['brand'].map(dt_brand)

# %%
laptop_df['os'].unique()
dt_os = {"Windows":0,"DOS":1,"Mac":2}
laptop_df['os']=laptop_df['os'].map(dt_os)

# %%
laptop_df['hdd'].unique()
dt_hdd={"1024 GB":1024,"0 GB":0,"512 GB":512,"2048 GB":2048}
laptop_df['hdd']=laptop_df['hdd'].map(dt_hdd)

# %%
laptop_df['msoffice'].unique()
dt_ms={"No":0,"Yes":1}
laptop_df['msoffice']=laptop_df['msoffice'].map(dt_ms)

# %%
laptop_df['ssd'].unique()
dt_ssd = {"0 GB":1,"512 GB":512,"256 GB":256,"128 GB":128,"1024 GB":1024,"2048 GB":2048,"3072 GB":3072}
laptop_df['Touchscreen']=laptop_df['Touchscreen'].map(dt_ssd)

# %%
laptop_df['Touchscreen'].unique()
dt_touch = {"No":0,"Yes":1}
laptop_df['Touchscreen']=laptop_df['Touchscreen'].map(dt_touch)

# %%
laptop_df['graphic_card_gb'].unique()
dt_graphic = {"0 GB":0,"2 GB":2,"4 GB":4,"6 GB":6,"8 GB":8}
laptop_df['graphic_card_gb']=laptop_df['graphic_card_gb'].map(dt_graphic)

# %%
laptop_df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
laptop_df['ram_gb'].unique()
dt_ram = {"4 GB":4,"8 GB":8,"16 GB":16,"32 GB":32}
laptop_df['ram_gb'] = laptop_df['ram_gb'].map(dt_ram)

# %%
laptop_df['os_bit'].unique()
laptop_df['os_bit'].value_counts()
dit = {"64-bit":6,"32-bit":3}
laptop_df['os_bit']=laptop_df['os_bit'].map(dit)

# %%
laptop_df['processor_brand'].unique()
laptop_df['processor_brand'].value_counts()
# Out:
# processor_brand
# Intel    594
# AMD      189
# M1        19
# Name: count, dtype: int64

# %%
dt={"Intel":1,"AMD":2,"M1":3}
dt
# Out:
# {'Intel': 1, 'AMD': 2, 'M1': 3}

# %%
laptop_df['processor_brand']= laptop_df['processor_brand'].map(dt)
laptop_df
# Out:
#      brand  processor_brand processor_name processor_gnrtn  ram_gb ram_type  \
# 0        1                1        Core i3            10th       4     DDR4
# 1        2                1        Core i3            10th       4     DDR4
# 2        2                1        Core i3            10th       4     DDR4
# 3        1                1        Core i5            10th       8     DDR4
# 4        1                1   Celeron Dual   Not Available       4     DDR4
# ..     ...              ...            ...             ...     ...      ...
# 818      1                2        Ryzen 9   Not Available       4     DDR4
# 819      1                2        Ryzen 9   Not Available       4     DDR4
# 820      1                2        Ryzen 9   Not Available       4     DDR4
# 821      1                2        Ryzen 9   Not Available       4     DDR4
# 822      2                2        Ryzen 5            10th       8     DDR4
#
#          ssd   hdd  os  os_bit  graphic_card_gb      weight     warranty  \
# 0       0 GB  1024   0       6                0      Casual  No warranty
# 1       0 GB  1024   0       6                0      Casual  No warranty
# 2       0 GB  1024   0       6                0      Casual  No warranty
# 3     512 GB     0   0       3                2      Casual  No warranty
# 4       0 GB   512   0       6                0      Casual  No warranty
# ..       ...   ...  ..     ...              ...         ...          ...
# 818  1024 GB     0   0       6                0      Casual       1 year
# 819  1024 GB     0   0       6                0      Casual       1 year
# 820  1024 GB     0   0       6                4      Casual       1 year
# 821  1024 GB     0   0       6                4      Casual       1 year
# 822   512 GB     0   1       6                0  ThinNlight  No warranty
#
#      Touchscreen  msoffice   Price   rating  Number of Ratings  \
# 0            NaN         0   34649  2 stars                  3
# 1            NaN         0   38999  3 stars                 65
# 2            NaN         0   39999  3 stars                  8
# 3            NaN         0   69990  3 stars                  0
# 4            NaN         0   26990  3 stars                  0
# ..           ...       ...     ...      ...                ...
# 818          NaN         0  135990  3 stars                  0
# 819          NaN         0  144990  3 stars                  0
# 820          NaN         0  149990  3 stars                  0
# 821          NaN         0  142990  3 stars                  0
# 822          NaN         0   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %%
laptop_df['ssd'].unique()
dt_ssd = {"0 GB":0,"512 GB":512,"256 GB":256,"1024 GB":1024,"2048 GB":2048,"3072 GB":3072,}
laptop_df['ssd']=laptop_df['ssd'].map(dt_ssd)

# %%
cal_df=laptop_df.select_dtypes(include='O') # esme apn catcorikal value ko alg kr rhe hai
cal_df
# Out:
#     processor_name processor_gnrtn ram_type      weight     warranty   rating
# 0          Core i3            10th     DDR4      Casual  No warranty  2 stars
# 1          Core i3            10th     DDR4      Casual  No warranty  3 stars
# 2          Core i3            10th     DDR4      Casual  No warranty  3 stars
# 3          Core i5            10th     DDR4      Casual  No warranty  3 stars
# 4     Celeron Dual   Not Available     DDR4      Casual  No warranty  3 stars
# ..             ...             ...      ...         ...          ...      ...
# 818        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 819        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 820        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 821        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 822        Ryzen 5            10th     DDR4  ThinNlight  No warranty  4 stars
#
# [802 rows x 6 columns]

# %%
laptop_df['processor_name'].unique()
dt_processor_name = {"Core i3":13,"Core i5":15,"Celeron Dual":0,"Ryzen 5":5,"Core i7":17,"Core i9":19,"M1":00,"Pentium Quad":000,"Ryzen 3":3,"Ryzen 7":7,"Ryzen 9":9}
laptop_df['processor_name']=laptop_df['processor_name'].map(dt_processor_name)

# %%
num_col = laptop_df.select_dtypes(exclude='O') # esme apn numerical value vale coloum alg kr liye 
num_col
# Out:
#      brand  processor_brand  processor_name  ram_gb     ssd   hdd  os  os_bit  \
# 0        1                1              13       4     0.0  1024   0       6
# 1        2                1              13       4     0.0  1024   0       6
# 2        2                1              13       4     0.0  1024   0       6
# 3        1                1              15       8   512.0     0   0       3
# 4        1                1               0       4     0.0   512   0       6
# ..     ...              ...             ...     ...     ...   ...  ..     ...
# 818      1                2               9       4  1024.0     0   0       6
# 819      1                2               9       4  1024.0     0   0       6
# 820      1                2               9       4  1024.0     0   0       6
# 821      1                2               9       4  1024.0     0   0       6
# 822      2                2               5       8   512.0     0   1       6
#
#      graphic_card_gb  Touchscreen  msoffice   Price  Number of Ratings  \
# 0                  0          NaN         0   34649                  3
# 1                  0          NaN         0   38999                 65
# 2                  0          NaN         0   39999                  8
# 3                  2          NaN         0   69990                  0
# 4                  0          NaN         0   26990                  0
# ..               ...          ...       ...     ...                ...
# 818                0          NaN         0  135990                  0
# 819                0          NaN         0  144990                  0
# 820                4          NaN         0  149990                  0
# 821                4          NaN         0  142990                  0
# 822                0          NaN         0   57490                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 14 columns]

# %%
laptop_df['brand'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8], dtype=int64)

# %%
cal_df
# Out:
#     processor_name processor_gnrtn ram_type      weight     warranty   rating
# 0          Core i3            10th     DDR4      Casual  No warranty  2 stars
# 1          Core i3            10th     DDR4      Casual  No warranty  3 stars
# 2          Core i3            10th     DDR4      Casual  No warranty  3 stars
# 3          Core i5            10th     DDR4      Casual  No warranty  3 stars
# 4     Celeron Dual   Not Available     DDR4      Casual  No warranty  3 stars
# ..             ...             ...      ...         ...          ...      ...
# 818        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 819        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 820        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 821        Ryzen 9   Not Available     DDR4      Casual       1 year  3 stars
# 822        Ryzen 5            10th     DDR4  ThinNlight  No warranty  4 stars
#
# [802 rows x 6 columns]

# %%
cal_df.drop(['weight','warranty','rating'],axis='columns')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[295], line 1
# ----> 1 cal_df.drop(['weight','warranty','rating'],axis='columns')
#
# File c:\Users\kumaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File c:\Users\kumaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File c:\Users\kumaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File c:\Users\kumaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['weight', 'warranty', 'rating'] not found in axis"

# %%
num_col
# Out:
#      brand  processor_brand  processor_name  ram_gb     ssd   hdd  os  os_bit  \
# 0        1                1              13       4     0.0  1024   0       6
# 1        2                1              13       4     0.0  1024   0       6
# 2        2                1              13       4     0.0  1024   0       6
# 3        1                1              15       8   512.0     0   0       3
# 4        1                1               0       4     0.0   512   0       6
# ..     ...              ...             ...     ...     ...   ...  ..     ...
# 818      1                2               9       4  1024.0     0   0       6
# 819      1                2               9       4  1024.0     0   0       6
# 820      1                2               9       4  1024.0     0   0       6
# 821      1                2               9       4  1024.0     0   0       6
# 822      2                2               5       8   512.0     0   1       6
#
#      graphic_card_gb  Touchscreen  msoffice   Price  Number of Ratings  \
# 0                  0          NaN         0   34649                  3
# 1                  0          NaN         0   38999                 65
# 2                  0          NaN         0   39999                  8
# 3                  2          NaN         0   69990                  0
# 4                  0          NaN         0   26990                  0
# ..               ...          ...       ...     ...                ...
# 818                0          NaN         0  135990                  0
# 819                0          NaN         0  144990                  0
# 820                4          NaN         0  149990                  0
# 821                4          NaN         0  142990                  0
# 822                0          NaN         0   57490                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 14 columns]

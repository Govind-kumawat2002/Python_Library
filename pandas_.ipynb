# %%
import pandas as pd

# %%
import pandas as pd 
df = pd.read_csv('laptopPrice.csv')
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
bike = pd.read_csv('Used_Bikes.csv')
bike
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
owner_group = bike.groupby('owner')
owner_group

# %%
bike['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
owner_group.get_group('First Owner')
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
owner_group.get_group('First Owner').head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
owner_group['price'].min()
# Out:
# owner
# First Owner              4400.0
# Fourth Owner Or More    11000.0
# Second Owner             7500.0
# Third Owner              7000.0
# Name: price, dtype: float64

# %%
bike['price'].min()
# Out:
# 4400.0

# %%
bike[bike['owner']=='First Owner'].min()
# Out:
# bike_name     BMW F750 GS 850cc
# price                    4400.0
# city                 24 Pargana
# kms_driven                  3.0
# owner               First Owner
# age                         1.0
# power                     100.0
# brand                       BMW
# dtype: object

# %%
bike
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
owner_group['age'].min()
# Out:
# owner
# First Owner             1.0
# Fourth Owner Or More    4.0
# Second Owner            2.0
# Third Owner             4.0
# Name: age, dtype: float64

# %%
owner_group['age'].max()
# Out:
# owner
# First Owner             43.0
# Fourth Owner Or More    37.0
# Second Owner            63.0
# Third Owner             43.0
# Name: age, dtype: float64

# %%
owner_group['age'].mean()
# Out:
# owner
# First Owner              7.684855
# Fourth Owner Or More    15.250000
# Second Owner            12.129095
# Third Owner             11.175926
# Name: age, dtype: float64

# %%
owner_group['age'].agg(mini_age='min',max_age='max',mean_age='mean')
# Out:
#                       mini_age  max_age   mean_age
# owner
# First Owner                1.0     43.0   7.684855
# Fourth Owner Or More       4.0     37.0  15.250000
# Second Owner               2.0     63.0  12.129095
# Third Owner                4.0     43.0  11.175926

# %%
age= owner_group['age'].agg(mini_age='min',max_age='max',mean_age='mean')
age.shape
# Out:
# (4, 3)

# %%
age.reset_index() # reset of index
# Out:
#                   owner  mini_age  max_age   mean_age
# 0           First Owner       1.0     43.0   7.684855
# 1  Fourth Owner Or More       4.0     37.0  15.250000
# 2          Second Owner       2.0     63.0  12.129095
# 3           Third Owner       4.0     43.0  11.175926

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
brand_group =df.groupby('brand')
brand_group

# %%
(pd.DataFrame(brand_group['ram_gb'].value_counts()))


# brand == 'dell'
# ram_type == '4 GB'
# Out:
#                count
# brand  ram_gb
# APPLE  16 GB      13
#        8 GB       13
#        32 GB       1
#        4 GB        1
# ASUS   8 GB      101
#        4 GB       89
#        16 GB      59
# Avita  8 GB       12
#        16 GB       1
#        4 GB        1
# DELL   8 GB       96
#        4 GB       39
#        16 GB      16
# HP     8 GB       63
#        4 GB       38
#        16 GB      35
# Lenovo 8 GB       78
#        4 GB       40
#        16 GB      26
# MSI    8 GB       27
#        16 GB      18
#        4 GB        5
# acer   8 GB       28
#        4 GB       13
#        16 GB       9
#        32 GB       1

# %%
(pd.DataFrame(brand_group['ssd'].value_counts()))
# Out:
#                 count
# brand  ssd
# APPLE  512 GB      13
#        1024 GB      8
#        256 GB       7
# ASUS   512 GB      99
#        1024 GB     59
#        256 GB      49
#        0 GB        39
#        128 GB       1
#        2048 GB      1
#        3072 GB      1
# Avita  256 GB       6
#        512 GB       6
#        0 GB         1
#        1024 GB      1
# DELL   512 GB      65
#        256 GB      57
#        0 GB        25
#        1024 GB      4
# HP     512 GB      83
#        0 GB        20
#        256 GB      17
#        1024 GB     14
#        128 GB       2
# Lenovo 512 GB      85
#        256 GB      31
#        0 GB        16
#        1024 GB     12
# MSI    512 GB      29
#        1024 GB      9
#        0 GB         8
#        256 GB       4
# acer   512 GB      18
#        0 GB        15
#        256 GB      13
#        1024 GB      4
#        2048 GB      1

# %%
((brand_group[['ssd','hdd','Touchscreen']].value_counts()).reset_index()).head(25)
# Out:
#     brand      ssd      hdd Touchscreen  count
# 0   APPLE   512 GB     0 GB          No     13
# 1   APPLE  1024 GB     0 GB          No      8
# 2   APPLE   256 GB     0 GB          No      7
# 3    ASUS   512 GB     0 GB          No     85
# 4    ASUS  1024 GB     0 GB          No     45
# 5    ASUS   256 GB     0 GB          No     26
# 6    ASUS     0 GB  1024 GB          No     25
# 7    ASUS   256 GB  1024 GB          No     22
# 8    ASUS     0 GB   512 GB          No     14
# 9    ASUS  1024 GB     0 GB         Yes     14
# 10   ASUS   512 GB     0 GB         Yes     14
# 11   ASUS   128 GB     0 GB         Yes      1
# 12   ASUS  2048 GB     0 GB          No      1
# 13   ASUS   256 GB     0 GB         Yes      1
# 14   ASUS  3072 GB     0 GB          No      1
# 15  Avita   256 GB     0 GB          No      6
# 16  Avita   512 GB     0 GB          No      6
# 17  Avita     0 GB   512 GB          No      1
# 18  Avita  1024 GB     0 GB          No      1
# ...

# %%
# ((brand_group[['ssd','hdd','Touchscreen']].value_counts()).).head(25)

# %%
df
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    DELL           Intel        Core i3            10th   4 GB     DDR4
# 1    DELL           Intel        Core i3            10th   4 GB     DDR4
# 2    DELL           Intel        Core i3            10th   4 GB     DDR4
# 3    DELL           Intel        Core i5            10th   8 GB     DDR4
# 4    DELL           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 818  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  DELL             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
Gb_group =df.groupby('ram_gb')
Gb_group

# %%
Gb_group[['Price']].mean()
# Gb_group.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\ops.py:863, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     861     preserve_dtype = True
# --> 863 result = self._aggregate_series_pure_python(obj, func)
#     865 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %%
Gb_group.agg({'Price':'min','Number of Ratings':'mean'})
# Out:
#          Price  Number of Ratings
# ram_gb
# 16 GB    56990          79.536723
# 32 GB   169990           1.500000
# 4 GB     16990         401.345133
# 8 GB     32490         370.114833

# %%
df[df['os']=='Windows']
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    DELL           Intel        Core i3            10th   4 GB     DDR4
# 1    DELL           Intel        Core i3            10th   4 GB     DDR4
# 2    DELL           Intel        Core i3            10th   4 GB     DDR4
# 3    DELL           Intel        Core i5            10th   8 GB     DDR4
# 4    DELL           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  DELL             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
df['os'].value_counts()
# Out:
# os
# Windows    779
# Mac         28
# DOS         16
# Name: count, dtype: int64

# %%
os_list=['Mac','DOS']

# %%
df[df['os'].isin(os_list)]
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 198  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 199  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 200  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 201  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 202  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 203  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 204  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 309  DELL           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  DELL           Intel        Core i5             8th   8 GB     DDR3
# 407  DELL           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  DELL           Intel        Core i5            10th  16 GB  LPDDR4X
# 433  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# ...

# %%
df['os'].str.contains('windo')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Name: os, Length: 823, dtype: bool

# %%
df.query("os=='Windows'")
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    DELL           Intel        Core i3            10th   4 GB     DDR4
# 1    DELL           Intel        Core i3            10th   4 GB     DDR4
# 2    DELL           Intel        Core i3            10th   4 GB     DDR4
# 3    DELL           Intel        Core i5            10th   8 GB     DDR4
# 4    DELL           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  DELL             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
df.query("os_bit=='64-bit'")
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    DELL           Intel        Core i3            10th   4 GB     DDR4
# 1    DELL           Intel        Core i3            10th   4 GB     DDR4
# 2    DELL           Intel        Core i3            10th   4 GB     DDR4
# 4    DELL           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    DELL           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 818  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  DELL             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  DELL             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...
